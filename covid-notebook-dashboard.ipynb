# %%
# Import libraries
import requests
import pandas as pd
import plotly.graph_objects as go
from IPython.display import display

# %%
# URL Link construction
timeline_url = "https://corona-api.com/timeline"

# %%
# API call
raw_timeline = requests.request("GET", timeline_url)
raw_timeline = raw_timeline.json()

# %%
# Transform data into pandas dataframe
df_timeline = pd.DataFrame(raw_timeline['data'])
df_timeline['updated_at'] = df_timeline['updated_at'].astype('datetime64')
df_timeline['date'] = df_timeline['date'].astype('datetime64')

# %%
display(df_timeline.info())
display(df_timeline.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   updated_at      146 non-null    datetime64[ns]
#  1   date            146 non-null    datetime64[ns]
#  2   deaths          146 non-null    int64
#  3   confirmed       146 non-null    int64
#  4   recovered       146 non-null    int64
#  5   active          146 non-null    int64
#  6   new_confirmed   146 non-null    int64
#  7   new_recovered   146 non-null    int64
#  8   new_deaths      146 non-null    int64
#  9   is_in_progress  1 non-null      object
# dtypes: datetime64[ns](2), int64(7), object(1)
# memory usage: 11.5+ KB
# None
#                updated_at       date  deaths  confirmed  recovered   active  \
# 0 2020-06-15 13:09:11.028 2020-06-15  435817    7976145    3908977  3631351
# 1 2020-06-13 01:33:15.000 2020-06-13  429680    7764044    3696143  3638221
# ...

# %%
# Show basic information from the data frame
summary = df_timeline.describe()
summary = summary.transpose()
summary.head()
# Out:
#                count          mean           std    min       25%        50%  \
# deaths         146.0  1.359730e+05  1.507651e+05   17.0   2775.75    55869.0
# confirmed      146.0  2.175795e+06  2.439065e+06  555.0  80883.00  1053493.0
# recovered      146.0  8.138942e+05  1.062570e+06   28.0  31014.75   217381.0
# active         146.0  1.225927e+06  1.257031e+06  510.0  47894.25   780243.0
# new_confirmed  146.0  5.493408e+04  4.702022e+04    1.0   2825.25    70732.5
#
#                       75%        max
# deaths          278157.00   435817.0
# confirmed      4000387.25  7976145.0
# recovered      1360682.75  3908977.0
# active         2361547.50  3638221.0
# new_confirmed    88184.75   212101.0

# %%
# Scatter plot for 3 variables
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['deaths'],
                    mode='markers',
                    name='deaths'))

fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['recovered'],
                    mode='lines+markers',
                    name='recovered'))

fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['active'],
                    mode='lines',
                    name='active'))

fig.show()
# Out:
# <div>
#
#
#             <div id="ef0bb474-68e1-42d9-9db4-9037c31dfcb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef0bb474-68e1-42d9-9db4-9037c31dfcb7")) {
#                     Plotly.newPlot(
#                         'ef0bb474-68e1-42d9-9db4-9037c31dfcb7',
# ...

# %%
# Scatter plot for 3 variables
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['new_deaths'],
                    mode='markers',
                    name='new deaths'))

fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['new_recovered'],
                    mode='lines+markers',
                    name='new recovered'))

fig.add_trace(go.Scatter(x=df_timeline['date'], y=df_timeline['new_confirmed'],
                    mode='lines',
                    name='new confirmed'))

fig.show()
# Out:
# <div>
#
#
#             <div id="19b9069e-2ec2-477f-ae71-cf66b2690cb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19b9069e-2ec2-477f-ae71-cf66b2690cb4")) {
#                     Plotly.newPlot(
#                         '19b9069e-2ec2-477f-ae71-cf66b2690cb4',
# ...

# %%
# URL Link construction
country_url = "https://corona-api.com/countries?include=timeline"

# %%
# API call
raw_country = requests.request("GET", country_url)
raw_country = raw_country.json()

# %%
# Transform data into pandas dataframe
df_country = pd.DataFrame(raw_country['data'])
display(df_country.head())
display(df_country.info())
# Out:
#                          coordinates            name code  population  \
# 0  {'latitude': 33, 'longitude': 65}     Afghanistan   AF  29121286.0
# 1  {'latitude': 41, 'longitude': 20}         Albania   AL   2986952.0
# 2    {'latitude': 0, 'longitude': 0}   Åland Islands   AX     26711.0
# 3    {'latitude': 0, 'longitude': 0}  American Samoa   AS     57881.0
# 4   {'latitude': 28, 'longitude': 3}         Algeria   DZ  34586184.0
#
#                  updated_at                             today  \
# 0  2020-06-15T18:29:22.473Z   {'deaths': 7, 'confirmed': 761}
# 1  2020-06-15T18:29:22.473Z    {'deaths': 0, 'confirmed': 69}
# 2  2020-06-15T18:29:22.473Z     {'deaths': 0, 'confirmed': 0}
# 3  2020-06-15T18:29:22.473Z     {'deaths': 0, 'confirmed': 0}
# 4  2020-06-15T18:29:22.473Z  {'deaths': 10, 'confirmed': 112}
#
#                                          latest_data  \
# 0  {'deaths': 478, 'confirmed': 25527, 'recovered...
# 1  {'deaths': 36, 'confirmed': 1590, 'recovered':...
# ...

# %%
# Show basic information from the data frame
summary_country = df_country.describe()
summary_country = summary_country.transpose()
summary_country.head()
# Out:
#             count          mean           std   min       25%        50%  \
# population  245.0  2.801242e+07  1.179886e+08  30.0  216494.0  4516220.0
#
#                    75%           max
# population  15878271.0  1.330044e+09
